# %%
# This data source is taken from https://en.wikipedia.org/wiki/List_of_countries_by_number_of_Internet_users
# This data list countries by internet users.
# This page does not have comparision with population density and internet users.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#   Country or Area Internet Users     Population  Rank Percentage Rank.1
# 0           China    765,367,947  1,409,517,397     1     54.30%    116
# 1           India    461,347,554  1,339,180,127     2     34.45%    145
# 2   United States    244,090,854    324,459,463     3     75.23%     68
# 3          Brazil    141,206,801    209,288,278     4     67.47%     83
# 4           Japan    115,845,120    127,484,450     5     90.87%     23

# %%
data['Population']=data['Population'].str.replace(',', '').astype(int)
data['Internet Users']=data['Internet Users'].str.replace(',', '').astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 6 columns):
# Country or Area    215 non-null object
# Internet Users     215 non-null int64
# Population         215 non-null int64
# Rank               215 non-null int64
# Percentage         215 non-null object
# Rank.1             215 non-null object
# dtypes: int64(3), object(3)
# memory usage: 10.2+ KB

# %%
data['Users Without Internet']= data['Population'] - data['Internet Users']
data.sort_values("Percentage", axis = 0, ascending = True, 
                 inplace = True, na_position ='last') 
data.head(10)
# Out:
#       Country or Area  Internet Users  Population  Rank Percentage Rank.1  \
# 185           Eritrea           66402     5068831   186      1.31%    209
# 115             Niger         2194985    21477348   116     10.22%    197
# 142  Papua New Guinea          924955     8251162   143     11.21%    196
# 126            Guinea         1449758    12717176   127     11.40%    195
# 93        Afghanistan         4068194    35530081    94     11.45%    194
# 180   Solomon Islands           72872      611343   181     11.92%    193
# 130             Haiti         1353986    10981229   131     12.33%    192
# 138              Togo          963795     7797694   139     12.36%    191
# 112              Mali         2358540    18541980   113     12.72%    190
# 136      Sierra Leone         1000575     7557212   137     13.24%    189
#
#      Users Without Internet
# 185                 5002429
# 115                19282363
# 142                 7326207
# 126                11267418
# ...

# %%
data.sort_values("Users Without Internet", axis = 0, ascending = False, 
                 inplace = True, na_position ='last') 
data.head(10)
# Out:
#                      Country or Area  Internet Users  Population  Rank  \
# 1                              India       461347554  1339180127     2
# 0                              China       765367947  1409517397     1
# 6                          Indonesia        85242816   263991379     7
# 24                           Nigeria        30557175   190015955    12
# 11                          Pakistan        61837331   220800300    25
# 26                        Bangladesh        30530435   164669751    27
# 36                          Ethiopia        19543075   104957438    37
# 2                      United States       244090854   324459463     3
# 65  Democratic Republic of the Congo         7011507    81339988    66
# 3                             Brazil       141206801   209288278     4
#
#    Percentage Rank.1  Users Without Internet
# 1      34.45%    145               877832573
# 0      54.30%    116               644149450
# 6      32.29%    150               178748563
# ...

# %%
bar_chart= data.head(10).plot.bar(x='Country or Area',y='Internet Users',subplots=True)

# %%
#  According to the data China has more internet users, but it's not taking into account the population of the country.
# This graph would have been more accurate if there was similar comparison country with equal population density,
# or taking comparison for every x% percent population and x% internet users.
